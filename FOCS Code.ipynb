# %%
# !pip uninstall crypto
# !pip uninstall pycrypto
# Out:
# WARNING: Skipping crypto as it is not installed.
# WARNING: Skipping pycrypto as it is not installed.

# %%
# %pip install pycrypto
# Out:
# Collecting pycrypto
#   Using cached pycrypto-2.6.1.tar.gz (446 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pycrypto
#   Building wheel for pycrypto (setup.py): started
#   Building wheel for pycrypto (setup.py): finished with status 'error'
#   Running setup.py clean for pycrypto
# Failed to build pycrypto
# Installing collected packages: pycrypto
#   Running setup.py install for pycrypto: started
#   Running setup.py install for pycrypto: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [149 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-39
#       creating build\lib.win-amd64-cpython-39\Crypto
#       copying lib\Crypto\pct_warnings.py -> build\lib.win-amd64-cpython-39\Crypto
#       copying lib\Crypto\__init__.py -> build\lib.win-amd64-cpython-39\Crypto
#       creating build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\hashalgo.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\HMAC.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\MD2.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\MD4.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\MD5.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\RIPEMD.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA224.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA256.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA384.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA512.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       creating build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\AES.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\ARC2.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\ARC4.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\blockalgo.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\Blowfish.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\CAST.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\DES.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\DES3.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\PKCS1_OAEP.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\PKCS1_v1_5.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\XOR.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       creating build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\asn1.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\Counter.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\number.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\py3compat.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\randpool.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\RFC1751.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\winrandom.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\_number_new.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       creating build\lib.win-amd64-cpython-39\Crypto\Random
#       copying lib\Crypto\Random\random.py -> build\lib.win-amd64-cpython-39\Crypto\Random
#       copying lib\Crypto\Random\_UserFriendlyRNG.py -> build\lib.win-amd64-cpython-39\Crypto\Random
#       copying lib\Crypto\Random\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Random
#       creating build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       copying lib\Crypto\Random\Fortuna\FortunaAccumulator.py -> build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       copying lib\Crypto\Random\Fortuna\FortunaGenerator.py -> build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       copying lib\Crypto\Random\Fortuna\SHAd256.py -> build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       copying lib\Crypto\Random\Fortuna\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       creating build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\fallback.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\nt.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\posix.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\rng_base.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest
#       copying lib\Crypto\SelfTest\st_common.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest
#       copying lib\Crypto\SelfTest\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\common.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_AES.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_ARC2.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_ARC4.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_Blowfish.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_CAST.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_DES.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_DES3.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_pkcs1_15.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_pkcs1_oaep.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_XOR.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\common.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_HMAC.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_MD2.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_MD4.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_MD5.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_RIPEMD.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA224.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA256.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA384.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA512.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\test_AllOrNothing.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\test_chaffing.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\test_KDF.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\test_rfc1751.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\test_DSA.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\test_ElGamal.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\test_importKey.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\test_RSA.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       copying lib\Crypto\SelfTest\Random\test_random.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       copying lib\Crypto\SelfTest\Random\test_rpoolcompat.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       copying lib\Crypto\SelfTest\Random\test__UserFriendlyRNG.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       copying lib\Crypto\SelfTest\Random\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       copying lib\Crypto\SelfTest\Random\Fortuna\test_FortunaAccumulator.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       copying lib\Crypto\SelfTest\Random\Fortuna\test_FortunaGenerator.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       copying lib\Crypto\SelfTest\Random\Fortuna\test_SHAd256.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       copying lib\Crypto\SelfTest\Random\Fortuna\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_fallback.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_generic.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_nt.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_posix.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_winrandom.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\test_asn1.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\test_Counter.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\test_number.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\test_winrandom.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Signature
#       copying lib\Crypto\SelfTest\Signature\test_pkcs1_15.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Signature
#       copying lib\Crypto\SelfTest\Signature\test_pkcs1_pss.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Signature
#       copying lib\Crypto\SelfTest\Signature\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Signature
#       creating build\lib.win-amd64-cpython-39\Crypto\Protocol
#       copying lib\Crypto\Protocol\AllOrNothing.py -> build\lib.win-amd64-cpython-39\Crypto\Protocol
#       copying lib\Crypto\Protocol\Chaffing.py -> build\lib.win-amd64-cpython-39\Crypto\Protocol
#       copying lib\Crypto\Protocol\KDF.py -> build\lib.win-amd64-cpython-39\Crypto\Protocol
#       copying lib\Crypto\Protocol\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Protocol
#       creating build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\DSA.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\ElGamal.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\pubkey.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\RSA.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\_DSA.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\_RSA.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\_slowmath.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       creating build\lib.win-amd64-cpython-39\Crypto\Signature
#       copying lib\Crypto\Signature\PKCS1_PSS.py -> build\lib.win-amd64-cpython-39\Crypto\Signature
#       copying lib\Crypto\Signature\PKCS1_v1_5.py -> build\lib.win-amd64-cpython-39\Crypto\Signature
#       copying lib\Crypto\Signature\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Signature
#       running build_ext
#       warning: GMP or MPIR library not found; Not building Crypto.PublicKey._fastmath.
#       building 'Crypto.Random.OSRNG.winrandom' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pycrypto
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for pycrypto did not run successfully.
#   │ exit code: 1
#   ╰─> [151 lines of output]
#       running install
#       c:\Users\hp\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-39
#       creating build\lib.win-amd64-cpython-39\Crypto
#       copying lib\Crypto\pct_warnings.py -> build\lib.win-amd64-cpython-39\Crypto
#       copying lib\Crypto\__init__.py -> build\lib.win-amd64-cpython-39\Crypto
#       creating build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\hashalgo.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\HMAC.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\MD2.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\MD4.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\MD5.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\RIPEMD.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA224.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA256.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA384.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\SHA512.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       copying lib\Crypto\Hash\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Hash
#       creating build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\AES.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\ARC2.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\ARC4.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\blockalgo.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\Blowfish.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\CAST.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\DES.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\DES3.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\PKCS1_OAEP.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\PKCS1_v1_5.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\XOR.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       copying lib\Crypto\Cipher\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Cipher
#       creating build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\asn1.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\Counter.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\number.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\py3compat.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\randpool.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\RFC1751.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\winrandom.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\_number_new.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       copying lib\Crypto\Util\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Util
#       creating build\lib.win-amd64-cpython-39\Crypto\Random
#       copying lib\Crypto\Random\random.py -> build\lib.win-amd64-cpython-39\Crypto\Random
#       copying lib\Crypto\Random\_UserFriendlyRNG.py -> build\lib.win-amd64-cpython-39\Crypto\Random
#       copying lib\Crypto\Random\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Random
#       creating build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       copying lib\Crypto\Random\Fortuna\FortunaAccumulator.py -> build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       copying lib\Crypto\Random\Fortuna\FortunaGenerator.py -> build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       copying lib\Crypto\Random\Fortuna\SHAd256.py -> build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       copying lib\Crypto\Random\Fortuna\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Random\Fortuna
#       creating build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\fallback.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\nt.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\posix.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\rng_base.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       copying lib\Crypto\Random\OSRNG\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Random\OSRNG
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest
#       copying lib\Crypto\SelfTest\st_common.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest
#       copying lib\Crypto\SelfTest\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\common.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_AES.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_ARC2.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_ARC4.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_Blowfish.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_CAST.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_DES.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_DES3.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_pkcs1_15.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_pkcs1_oaep.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\test_XOR.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       copying lib\Crypto\SelfTest\Cipher\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Cipher
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\common.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_HMAC.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_MD2.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_MD4.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_MD5.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_RIPEMD.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA224.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA256.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA384.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\test_SHA512.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       copying lib\Crypto\SelfTest\Hash\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Hash
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\test_AllOrNothing.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\test_chaffing.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\test_KDF.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\test_rfc1751.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       copying lib\Crypto\SelfTest\Protocol\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Protocol
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\test_DSA.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\test_ElGamal.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\test_importKey.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\test_RSA.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       copying lib\Crypto\SelfTest\PublicKey\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\PublicKey
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       copying lib\Crypto\SelfTest\Random\test_random.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       copying lib\Crypto\SelfTest\Random\test_rpoolcompat.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       copying lib\Crypto\SelfTest\Random\test__UserFriendlyRNG.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       copying lib\Crypto\SelfTest\Random\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       copying lib\Crypto\SelfTest\Random\Fortuna\test_FortunaAccumulator.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       copying lib\Crypto\SelfTest\Random\Fortuna\test_FortunaGenerator.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       copying lib\Crypto\SelfTest\Random\Fortuna\test_SHAd256.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       copying lib\Crypto\SelfTest\Random\Fortuna\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\Fortuna
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_fallback.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_generic.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_nt.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_posix.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\test_winrandom.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       copying lib\Crypto\SelfTest\Random\OSRNG\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Random\OSRNG
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\test_asn1.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\test_Counter.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\test_number.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\test_winrandom.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       copying lib\Crypto\SelfTest\Util\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Util
#       creating build\lib.win-amd64-cpython-39\Crypto\SelfTest\Signature
#       copying lib\Crypto\SelfTest\Signature\test_pkcs1_15.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Signature
#       copying lib\Crypto\SelfTest\Signature\test_pkcs1_pss.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Signature
#       copying lib\Crypto\SelfTest\Signature\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\SelfTest\Signature
#       creating build\lib.win-amd64-cpython-39\Crypto\Protocol
#       copying lib\Crypto\Protocol\AllOrNothing.py -> build\lib.win-amd64-cpython-39\Crypto\Protocol
#       copying lib\Crypto\Protocol\Chaffing.py -> build\lib.win-amd64-cpython-39\Crypto\Protocol
#       copying lib\Crypto\Protocol\KDF.py -> build\lib.win-amd64-cpython-39\Crypto\Protocol
#       copying lib\Crypto\Protocol\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Protocol
#       creating build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\DSA.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\ElGamal.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\pubkey.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\RSA.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\_DSA.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\_RSA.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\_slowmath.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       copying lib\Crypto\PublicKey\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\PublicKey
#       creating build\lib.win-amd64-cpython-39\Crypto\Signature
#       copying lib\Crypto\Signature\PKCS1_PSS.py -> build\lib.win-amd64-cpython-39\Crypto\Signature
#       copying lib\Crypto\Signature\PKCS1_v1_5.py -> build\lib.win-amd64-cpython-39\Crypto\Signature
#       copying lib\Crypto\Signature\__init__.py -> build\lib.win-amd64-cpython-39\Crypto\Signature
#       running build_ext
#       warning: GMP or MPIR library not found; Not building Crypto.PublicKey._fastmath.
#       building 'Crypto.Random.OSRNG.winrandom' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pycrypto
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !pip install pycryptodomex
# Out:
# Requirement already satisfied: pycryptodomex in c:\users\hp\anaconda3\lib\site-packages (3.15.0)

# %%
# Install cryptodome from terminal
# pip install pycryptodome

# Then import DES3 for Encryption and md5 for key
import os
from Cryptodome.Cipher import DES3
from hashlib import md5

# For selecting operation from given choice
while True:
    print('Choose operation to be done:\n\t1- Encryption\n\t2- Decryption')
    operation = input('Your Choice: ')
    if operation not in ['1', '2']:
        break

    os.chdir(r'C:\Users\hp\Desktop\projects\FOCS PROJECT')

    # Image / File Path for operation
    file_name = input('File name: ')
    
    # Key for performing Triple DES algorithm
    key = input('TDES key: ')

    # Encode given key to 16 byte ascii key with md5 operation
    key_hash = md5(key.encode('ascii')).digest()

    tdes_key = DES3.adjust_key_parity(key_hash)
    cipher = DES3.new(tdes_key, DES3.MODE_EAX, nonce=b'0')

    # Open & read file from given path
    with open(file_name, 'rb') as input_file:
        file_bytes = input_file.read()

        if operation == '1':
            # Perform Encryption operation
            new_file_bytes = cipher.encrypt(file_bytes)
        else:
            # Perform Decryption operation
            new_file_bytes = cipher.decrypt(file_bytes)

    # Write updated values in file from given path
    with open(file_name, 'wb') as output_file:
        output_file.write(new_file_bytes)
        # print('Operation Done!')
        break

# Code Complete!
# Out:
# Choose operation to be done:
# 	1- Encryption
# 	2- Decryption
